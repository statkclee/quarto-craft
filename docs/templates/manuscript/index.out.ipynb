# %% [markdown]
# # 논문 제목
#
# 부제목
#
# 저자명 [![](data:image/png;base64,...)](https://orcid.org/0000-0000-0000-0000) (소속 기관)
# 2026년 05월 16일
#
# 초록을 여기에 작성합니다. 연구의 목적, 방법, 결과, 결론을 간략하게 요약합니다. 200~300자 내외로 작성하는 것을 권장합니다.
#
# ## 1 서론
#
# 연구 배경과 목적을 서술합니다. 선행 연구를 검토하고 ([Doe 와/과 Kim 2024년](#ref-doe2024)) 본 연구의 필요성과 기여점을 명확히 제시합니다.
#
# ## 2 연구 방법
#
# ### 2.1 데이터
#
# 사용한 데이터의 출처, 수집 방법, 전처리 과정을 설명합니다.
#
# ### 2.2 분석 방법
#
# 적용한 통계적·분석적 방법론을 설명합니다.

# %%
plot(1:10, (1:10)^2, type = "l",
     xlab = "X축", ylab = "Y축",
     main = "예시 그래프")

# %% [markdown]
# ## 3 결과
#
# <a href="#fig-example" class="quarto-xref">그림 1</a> 에서 확인할 수 있듯이 분석 결과를 설명합니다.
#
# ## 4 논의
#
# 결과의 의미와 한계점을 논의합니다.
#
# ## 5 결론
#
# 연구의 주요 결론과 향후 연구 방향을 제시합니다.
#
# ## 참고문헌
#
# Doe, Jane, 와/과 Minjoo Kim. 2024년. “Sample Reference Article”. *Journal of Data Science* 12 (3): 45–67. <https://doi.org/10.0000/example>.
